# %%
import tensorflow as tf
tf.random.set_seed(777)     # 시드 설정

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import mse

# 데이터 준비
x = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y = np.array([[0], [1], [1], [1]])

# 모델 구성
model = Sequential()
# 단층 퍼셉트론 구성
model.add(Dense(1, input_shape = (2, ), activation = 'linear'))

# 모델 준비
model.compile(optimizer =SGD(), loss = mse, metrics = ['acc'])
                                                    # 리스트 형태로 평가지표를 전달
# 학습시키기
model.fit(x, y, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 246ms/step - loss: 1.4290 - acc: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3602 - acc: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2956 - acc: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2349 - acc: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1779 - acc: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1242 - acc: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0738 - acc: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0264 - acc: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9819 - acc: 0.5000
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9399 - acc: 0.5000
# Epoch 11/500
# ...

# %%
model.get_weights()
# Out:
# [array([[0.49431452],
#         [0.37552658]], dtype=float32),
#  array([0.3271933], dtype=float32)]

# %%
# 벡터 내적

import tensorflow as tf

x = tf.random.uniform((10, 5))          # uniform 분포에서 해당 크기만큼 난수 생성
w = tf.random.uniform((5, 3))
d = tf.matmul(x, w)             # (10, 5) * (5, 3)

print(f'x와 w의 벡터 내적의 결과 크기 : {d.shape}')
print(f'x와 w의 벡터 내적의 결과 : {d}')
# Out:
# x와 w의 벡터 내적의 결과 크기 : (10, 3)
# x와 w의 벡터 내적의 결과 : [[1.3457344  1.5384569  0.9316881 ]
#  [0.6532685  0.9654017  0.4554649 ]
#  [0.6660566  0.551713   0.44132873]
#  [1.4618833  1.3292269  1.070152  ]
#  [1.7038811  1.5466676  1.0185009 ]
#  [1.8761816  1.9616349  1.3329606 ]
#  [1.150184   1.6019403  0.99052835]
#  [1.005852   1.2082226  0.91563463]
#  [0.7388882  0.7342882  0.50917685]
#  [2.09891    1.8863548  1.5475826 ]]

# %%
import tensorflow as tf
tf.random.set_seed(777)     # 시드 설정

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import mse

# 데이터 준비
x = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y = np.array([[0], [1], [1], [1]])

# 모델 구성
model = Sequential()
model.add(Dense(32, input_shape = (2, ), activation = 'relu'))
# 다층 퍼셉트론 구성
model.add(Dense(1, activation = 'sigmoid'))

# 모델 준비
model.compile(optimizer =RMSprop(), loss = mse, metrics = ['acc'])
                                                    # 리스트 형태로 평가지표를 전달
# 학습시키기
model.fit(x, y, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 392ms/step - loss: 0.3054 - acc: 0.2500
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2966 - acc: 0.0000e+00
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2907 - acc: 0.0000e+00
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2858 - acc: 0.0000e+00
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2816 - acc: 0.0000e+00
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2777 - acc: 0.0000e+00
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2742 - acc: 0.0000e+00
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2709 - acc: 0.0000e+00
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2678 - acc: 0.2500
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2649 - acc: 0.2500
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# 시그모이드 함수
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# 하이퍼볼릭 탄젠트 함수
def tanh(x):
    return list(map(lambda x : math.tanh(x), x))

# relu 함수
def relu(x):
    result = []
    for ele in x:
        if(ele <= 0):
            result.append(0)
        else:
            result.append(ele)
           
    return result

# 시그모이드, 하이퍼볼릭 탄젠트, relu 함수 그리기
x = np.linspace(-4, 4, 100)
sig = sigmoid(x)
t = tanh(x)
rel = relu(x)
plt.plot(x, sig)
plt.plot(x, t)
plt.plot(x, rel)
plt.show()

# %%
# 경사 하강법 실행

import numpy as np
import matplotlib.pyplot as plt

lr_list = [0.001, 0.1, 0.5, 0.9]    # 여러가지 학습률을 사용하여 값의 변화를 관찰

def get_derivative(lr):
    w_old = 2
    derivative = [w_old]

    y = [w_old ** 2]    # 손실함수를 y x^2로 정의

    for i in range(1, 10):
        # 먼저 해당 위치에서 미분값을 구합니다.
        dev_value = w_old * 2

        # 위의 값을 이용하여 가중치를 업데이트
        w_new = w_old - lr * dev_value
        w_old = w_new

        derivative.append(w_old)        # save the updated weigt
        y.append(w_old ** 2)            # save the updated loss

    return derivative, y

x = np.linspace(-2, 2, 50)              # -2~2의 범위를 50구간으로 나눈 배열을 반환
x_square = [i ** 2 for i in x] 

fig = plt.figure(figsize= (12, 7))

for i, lr in enumerate(lr_list) :
    derivative, y = get_derivative(lr)
    ax = fig.add_subplot(2, 2, i + 1)
    ax.scatter(derivative, y, color='red')
    ax.plot(x, x_square)
    ax.title.set_text('lr ='+ str (lr))

plt.show()

# %%
# 평균 제곱 오차 회귀 문제
model.compile(optimizer = RMSprop(), loss = 'mse', metrics=['acc'])

# 이항 분류 문제
model.compile(optimizer = RMSprop(), loss = 'binary_crossentropy', metrics=['acc'])

# 다항 분류 문제
model.compile(optimizer = RMSprop(), loss = 'categorical_crossentropy', metrics=['acc'])

# %% [markdown]
# <a href="https://colab.research.google.com/github/jayU000/TensorFlow_2022/blob/main/Tf_boston_housing_221010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tensorflow.keras.datasets.boston_housing import load_data

(x_train, y_train), (x_test, y_test) = load_data(path='boston_housing.npz', 
                                                 test_split=0.2,
                                                 seed=777)
# Out:
# ...
# 65536/57026 [==================================] - 0s 0us/step

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (404, 13) (404,)
# (102, 13) (102,)

# %%
import numpy as np

mean = np.mean(x_train, axis=0)
std = np.std(x_train, axis=0) 

x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
                                                  test_size=0.33,
                                                  random_state=777)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(13, )))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=300, 
                    validation_data=(x_val, y_val))
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/300
# 9/9 [==============================] - 1s 24ms/step - loss: 565.0167 - mae: 22.1022 - val_loss: 619.6464 - val_mae: 22.6968
# Epoch 2/300
# 9/9 [==============================] - 0s 5ms/step - loss: 543.0067 - mae: 21.6072 - val_loss: 596.6820 - val_mae: 22.1996
# Epoch 3/300
# 9/9 [==============================] - 0s 6ms/step - loss: 522.0170 - mae: 21.1323 - val_loss: 573.4647 - val_mae: 21.6894
# Epoch 4/300
# 9/9 [==============================] - 0s 7ms/step - loss: 499.4401 - mae: 20.6007 - val_loss: 546.4916 - val_mae: 21.0859
# Epoch 5/300
# 9/9 [==============================] - 0s 7ms/step - loss: 471.8544 - mae: 19.9503 - val_loss: 512.9370 - val_mae: 20.3177
# Epoch 6/300
# 9/9 [==============================] - 0s 6ms/step - loss: 438.2245 - mae: 19.1069 - val_loss: 470.5870 - val_mae: 19.3327
# Epoch 7/300
# 9/9 [==============================] - 0s 5ms/step - loss: 395.7459 - mae: 18.0460 - val_loss: 419.5194 - val_mae: 18.0869
# Epoch 8/300
# ...

# %%
from tensorflow.keras.datasets.boston_housing import load_data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
from sklearn.model_selection import KFold

(x_train, y_train), (x_test, y_test) = load_data(path='boston_housing.npz',
                                                 test_split=0.2,
                                                 seed=777)

mean = np.mean(x_train, axis=0)
std = np.std(x_train, axis=0)

x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

k = 3

kfold = KFold(n_splits=k, shuffle=True, random_state=777)


def get_model():
  model = Sequential()
  model.add(Dense(64, activation='relu', input_shape=(13, )))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1))

  model.compile(optimizer='adam', loss='mse', metrics=['mae'])

  return model


mae_list = []

for train_index, val_index in kfold.split(x_train):
  x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
  y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

  model = get_model()

  model.fit(x_train_fold, y_train_fold, epochs=200,
            validation_data = (x_val_fold, y_val_fold))
  
  _, test_mae = model.evaluate(x_test, y_test)
  mae_list.append(test_mae)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 1s 18ms/step - loss: 513.7641 - mae: 20.9477 - val_loss: 552.6103 - val_mae: 21.2281
# Epoch 2/200
# 9/9 [==============================] - 0s 6ms/step - loss: 476.7777 - mae: 20.0636 - val_loss: 509.1535 - val_mae: 20.2190
# Epoch 3/200
# 9/9 [==============================] - 0s 7ms/step - loss: 433.4117 - mae: 18.9696 - val_loss: 455.8002 - val_mae: 18.9267
# Epoch 4/200
# 9/9 [==============================] - 0s 5ms/step - loss: 379.9764 - mae: 17.6081 - val_loss: 393.1169 - val_mae: 17.3050
# Epoch 5/200
# 9/9 [==============================] - 0s 5ms/step - loss: 319.0029 - mae: 15.9595 - val_loss: 322.7619 - val_mae: 15.3238
# Epoch 6/200
# 9/9 [==============================] - 0s 5ms/step - loss: 254.9619 - mae: 14.0255 - val_loss: 249.2197 - val_mae: 13.0378
# Epoch 7/200
# 9/9 [==============================] - 0s 5ms/step - loss: 188.6378 - mae: 11.8361 - val_loss: 182.8759 - val_mae: 10.6685
# Epoch 8/200
# ...

# %%
print(mae_list)
# Out:
# [2.2243058681488037, 2.138496160507202, 2.188382387161255]

# %%
print(np.mean(mae_list))
# Out:
# 2.1837281386057534
